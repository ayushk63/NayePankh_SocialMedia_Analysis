# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Documents/NayePankh DA Project/NayePankhDataset.csv")
df.head()
# Out:
#     Platform  Followers  Posts  Comments  Likes
# 0   LinkedIn       5000      0         0      0
# 1    Youtube       4090      3       133    139
# 2  Instagram      15345    284      3843  51664
# 3          X        933      0         0      0
# 4   Facebook       1400    342       418   2834

# %%
df.describe()
# Out:
#           Followers       Posts    Comments         Likes
# count      5.000000    5.000000     5.00000      5.000000
# mean    5353.600000  125.800000   878.80000  10927.400000
# std     5846.418759  172.119726  1665.80422  22804.491987
# min      933.000000    0.000000     0.00000      0.000000
# 25%     1400.000000    0.000000     0.00000      0.000000
# 50%     4090.000000    3.000000   133.00000    139.000000
# 75%     5000.000000  284.000000   418.00000   2834.000000
# max    15345.000000  342.000000  3843.00000  51664.000000

# %%
corr = df.drop(columns = {'Platform'}).corr()
corr
# Out:
#            Followers     Posts  Comments     Likes
# Followers   1.000000  0.368096  0.938914  0.946591
# Posts       0.368096  1.000000  0.594663  0.558513
# Comments    0.938914  0.594663  1.000000  0.998563
# Likes       0.946591  0.558513  0.998563  1.000000

# %%
plt.title("Correlation Heatmap")
sns.heatmap(corr)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %%
sns.catplot(df, x = 'Platform', y = 'Followers', kind = 'bar', color = 'g')

# %%
sns.catplot(df, x = 'Comments', y = 'Platform', kind = 'bar', color = 'purple')

# %%
sns.catplot(df, x = 'Platform', y = 'Likes', kind = 'bar', color = 'r')
